# %%
import os
import pdfplumber
import pandas as pd

# Define input and output directories
input_folder = 'C:\\Users\\manja\\Desktop\\Marriage\\Input\\'
output_folder = 'C:\\Users\\manja\\Desktop\\Marriage\\Output\\'

# Iterate over each PDF file in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith('.pdf'):
        pdf_path = os.path.join(input_folder, filename)
        
        # Extracting the name without extension for the output text file
        file_name_without_extension = os.path.splitext(filename)[0]
        txt_path = os.path.join(output_folder, file_name_without_extension + '.txt')
        
        # Open the PDF file and extract text
        with pdfplumber.open(pdf_path) as source:
            with open(txt_path, 'w', encoding='utf-8') as extract:
                pg_num = len(source.pages)
                for i in range(pg_num):
                    pg_obj = source.pages[i]
                    txt_obj = pg_obj.extract_text()
                    extract.write(txt_obj)

# Now let's read all text files in the output folder and create a DataFrame
all_data = []
for txt_filename in os.listdir(output_folder):
    if txt_filename.endswith('.txt'):
        txt_filepath = os.path.join(output_folder, txt_filename)
        with open(txt_filepath) as f:
            data = f.readlines()
            all_data.extend(data)

# Create DataFrame from the extracted text
df = pd.DataFrame(all_data)
print(df)
# Out:
#                                                0
# 0                                Example table\n
# 1          This is an example of a data table.\n
# 2                                      Results\n
# 3                                      Ballots\n
# 4                           Disability Ballots\n
# 5                     Participants Incomplete/\n
# 6          Category Completed Accuracy Time to\n
# 7                                   Terminated\n
# 8                                     complete\n
# 9         Blind 5 1 4 34.5%, n=1 1199 sec, n=1\n
# 10    Low Vision 5 2 3 98.3% n=2 1716 sec, n=3\n
# 11                (97.7%, n=3) (1934 sec, n=2)\n
# 12  Dexterity 5 4 1 98.3%, n=4 1672.1 sec, n=4\n
# 13       Mobility 3 3 0 95.4%, n=3 1416 sec, n=3
# 14                               Example table\n
# 15         This is an example of a data table.\n
# 16                                     Results\n
# 17                                     Ballots\n
# 18                          Disability Ballots\n
# 19                    Participants Incomplete/\n
# 20         Category Completed Accuracy Time to\n
# 21                                  Terminated\n
# 22                                    complete\n
# 23        Blind 5 1 4 34.5%, n=1 1199 sec, n=1\n
# 24    Low Vision 5 2 3 98.3% n=2 1716 sec, n=3\n
# 25                (97.7%, n=3) (1934 sec, n=2)\n
# 26  Dexterity 5 4 1 98.3%, n=4 1672.1 sec, n=4\n
# 27       Mobility 3 3 0 95.4%, n=3 1416 sec, n=3
# 28                               Example table\n
# 29         This is an example of a data table.\n
# 30                                     Results\n
# 31                                     Ballots\n
# 32                          Disability Ballots\n
# 33                    Participants Incomplete/\n
# 34         Category Completed Accuracy Time to\n
# 35                                  Terminated\n
# 36                                    complete\n
# 37        Blind 5 1 4 34.5%, n=1 1199 sec, n=1\n
# 38    Low Vision 5 2 3 98.3% n=2 1716 sec, n=3\n
# 39                (97.7%, n=3) (1934 sec, n=2)\n
# 40  Dexterity 5 4 1 98.3%, n=4 1672.1 sec, n=4\n
# 41       Mobility 3 3 0 95.4%, n=3 1416 sec, n=3
# 42                               Example table\n
# 43         This is an example of a data table.\n
# 44                                     Results\n
# 45                                     Ballots\n
# 46                          Disability Ballots\n
# 47                    Participants Incomplete/\n
# 48         Category Completed Accuracy Time to\n
# 49                                  Terminated\n
# 50                                    complete\n
# 51        Blind 5 1 4 34.5%, n=1 1199 sec, n=1\n
# 52    Low Vision 5 2 3 98.3% n=2 1716 sec, n=3\n
# 53                (97.7%, n=3) (1934 sec, n=2)\n
# 54  Dexterity 5 4 1 98.3%, n=4 1672.1 sec, n=4\n
# 55       Mobility 3 3 0 95.4%, n=3 1416 sec, n=3
